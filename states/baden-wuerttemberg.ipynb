# %%
import re

import pandas as pd

# %%
PATH = 'raw/Pflegestatistik_2013_Baden-Württemberg.xls'
data = []

# %%
AGS_RE = re.compile(r'(LKR|SKR)\s+(\d{3})')

def get_ags_for_name(name):
    match = AGS_RE.search(name)
    if match is None:
        print(name)
        return None
    ags = '08%s' % match.group(2)
    return ags


def get_column_values(df, mapping, prefix):
    for c in df.columns:
        ags = get_ags_for_name(c)
        if ags is None:
            continue

        for k, v in mapping.items():
            val = df[df['key'].str.contains(k, regex=False).fillna(False)].iloc[0][c]
            val = re.sub('(\d+),(\d{2})', '\\1.\\2', str(val))
            if val in ('–', '-'):
                val = 0.0
            yield ags, prefix, v, float(val)

# %%
df = pd.read_excel(PATH, sheetname='Vergütung', skiprows=5)
df = df.rename(columns={
    'Art der Vergütung ': 'key'
})

cost_mapping = {
    'Pflegeklasse 1': 'costs_nursing_class_1',
    'Pflegeklasse 2': 'costs_nursing_class_2',
    'Pflegeklasse 3': 'costs_nursing_class_3',
    'Verpflegung': 'food',
}

data.extend(list(get_column_values(df, cost_mapping, 'costs')))
df.head()
# Out:
# key
# Baden-Württemberg
#    key  Stuttgart, SKR 111 Böblingen, LKR 115  Esslingen, LKR 116  \
# 0  NaN                 NaN                NaN                 NaN
# 1  NaN                 NaN                NaN                 NaN
# 2  NaN                 NaN                NaN                 NaN
# 3  NaN                 NaN                NaN                 NaN
# 4  NaN                 NaN                NaN                 NaN
#
#    Göppingen, LKR 117  Ludwigsburg, LKR 118  Rems-Murr-Kreis, LKR    119  \
# 0                 NaN                   NaN                          NaN
# 1                 NaN                   NaN                          NaN
# 2                 NaN                   NaN                          NaN
# 3                 NaN                   NaN                          NaN
# 4                 NaN                   NaN                          NaN
#
#    Heilbronn, SKR 121  Heilbronn, LKR 125  Hohenlohekreis, LKR 126  \
# 0                 NaN                 NaN                      NaN
# 1                 NaN                 NaN                      NaN
# 2                 NaN                 NaN                      NaN
# 3                 NaN                 NaN                      NaN
# 4                 NaN                 NaN                      NaN
#
#          ...          Reutlingen, LKR 415  Tübingen, LKR 416  \
# 0        ...                          NaN                NaN
# 1        ...                          NaN                NaN
# 2        ...                          NaN                NaN
# 3        ...                          NaN                NaN
# 4        ...                          NaN                NaN
#
#    Zollernalbkreis, LKR 417  Ulm, SKR 421  Alb-Donau-Kreis, LKR 425  \
# 0                       NaN           NaN                       NaN
# 1                       NaN           NaN                       NaN
# 2                       NaN           NaN                       NaN
# 3                       NaN           NaN                       NaN
# 4                       NaN           NaN                       NaN
#
#    Biberach, LKR 426  Bodenseekreis, LKR 435  Ravensburg, LKR 436  \
# 0                NaN                     NaN                  NaN
# 1                NaN                     NaN                  NaN
# 2                NaN                     NaN                  NaN
# 3                NaN                     NaN                  NaN
# 4                NaN                     NaN                  NaN
#
#    Sigmaringen, LKR 437  Baden-Württemberg
# 0                   NaN                NaN
# 1                   NaN                NaN
# 2                   NaN                NaN
# 3                   NaN                NaN
# 4                   NaN                NaN
#
# [5 rows x 46 columns]

# %%
df = pd.read_excel(PATH, sheetname='verfügbare Plätze Betten', skiprows=4)
df = df.rename(columns={
    'Art der verfügbaren Plätze': 'key'
})

bed_mapping = {
  '1-Bett-Zimmern': '1-bed',
  '2-Bett-Zimmern': '2-bed',
  '3-Bett-Zimmern': '3-bed',
  '4 und mehr-Bett-Zimmern': '4-bed'
}
data.extend(list(get_column_values(df, bed_mapping, 'beds')))
df.head()
# Out:
# key
# Baden-Württemberg
#    key  Stuttgart, SKR 111 Böblingen, LKR 115 Esslingen, LKR 116  \
# 0  NaN                 NaN                NaN                NaN
# 1  NaN                 NaN                NaN                NaN
# 2  NaN                 NaN                NaN                NaN
# 3  NaN                 NaN                NaN                NaN
# 4  NaN                 NaN                NaN                NaN
#
#   Göppingen, LKR 117 Ludwigsburg, LKR 118 Rems-Murr-Kreis, LKR    119  \
# 0                NaN                  NaN                         NaN
# 1                NaN                  NaN                         NaN
# 2                NaN                  NaN                         NaN
# 3                NaN                  NaN                         NaN
# 4                NaN                  NaN                         NaN
#
#   Heilbronn, SKR 121 Heilbronn, LKR 125 Hohenlohekreis, LKR 126  \
# 0                NaN                NaN                     NaN
# 1                NaN                NaN                     NaN
# 2                NaN                NaN                     NaN
# 3                NaN                NaN                     NaN
# 4                NaN                NaN                     NaN
#
#          ...        Reutlingen, LKR 415 Tübingen, LKR 416  \
# 0        ...                        NaN               NaN
# 1        ...                        NaN               NaN
# 2        ...                        NaN               NaN
# 3        ...                        NaN               NaN
# 4        ...                        NaN               NaN
#
#   Zollernalbkreis, LKR 417 Ulm, SKR 421 Alb-Donau-Kreis, LKR 425  \
# 0                      NaN          NaN                      NaN
# 1                      NaN          NaN                      NaN
# 2                      NaN          NaN                      NaN
# 3                      NaN          NaN                      NaN
# 4                      NaN          NaN                      NaN
#
#    Biberach, LKR 426 Bodenseekreis, LKR 435 Ravensburg, LKR 436  \
# 0                NaN                    NaN                 NaN
# 1                NaN                    NaN                 NaN
# 2                NaN                    NaN                 NaN
# 3                NaN                    NaN                 NaN
# 4                NaN                    NaN                 NaN
#
#   Sigmaringen, LKR 437 Baden-Württemberg
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
#
# [5 rows x 46 columns]

# %%
df = pd.read_excel(PATH, sheetname='Personal', skiprows=4)
df = df.rename(columns={
    'Beschäftigungsverhältnis/             Tätigkeitsbereich/              Berufsabschluss': 'key'
})

personal_mapping = {
    'Vollzeitbeschäftigt': 'fully_employed',
#     'Teilzeitbeschäftigt': 'part-time',
    '   - über 50 % ': 'part-time-1',
    '      beschäftigt ': 'part-time-2',
    '   - geringfügig beschäftigt ': 'part-time-3',
    'Pflege und Betreuung': 'nursing_and_care',
    'soziale Betreuung': 'social_care',
    'zusätzliche Betreuung (§ 87b SGB XI)': 'other_care',
    'Personal insgesamt': 'total_personnel'
}

data.extend(list(get_column_values(df, personal_mapping, 'personal')))
df.head()
# Out:
# key
# Baden-Württemberg
#    key  Stuttgart, SKR 111  Böblingen, LKR 115  Esslingen, LKR 116  \
# 0  NaN                 NaN                 NaN                 NaN
# 1  NaN                 NaN                 NaN                 NaN
# 2  NaN                 NaN                 NaN                 NaN
# 3  NaN                 NaN                 NaN                 NaN
# 4  NaN  Personal insgesamt  Personal insgesamt  Personal insgesamt
#
#    Göppingen, LKR 117 Ludwigsburg, LKR 118 Rems-Murr-Kreis, LKR 119  \
# 0                 NaN                  NaN                      NaN
# 1                 NaN                  NaN                      NaN
# 2                 NaN                  NaN                      NaN
# 3                 NaN                  NaN                      NaN
# 4  Personal insgesamt   Personal insgesamt       Personal insgesamt
#
#    Heilbronn, SKR 121  Heilbronn, LKR 125 Hohenlohekreis, LKR 126  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4  Personal insgesamt  Personal insgesamt      Personal insgesamt
#
#           ...         Reutlingen, LKR 415   Tübingen, LKR 416  \
# 0         ...                         NaN                 NaN
# 1         ...                         NaN                 NaN
# 2         ...                         NaN                 NaN
# 3         ...                         NaN                 NaN
# 4         ...          Personal insgesamt  Personal insgesamt
#
#   Zollernalbkreis, LKR 417        Ulm, SKR 421 Alb-Donau-Kreis, LKR 425  \
# 0                      NaN                 NaN                      NaN
# 1                      NaN                 NaN                      NaN
# 2                      NaN                 NaN                      NaN
# 3                      NaN                 NaN                      NaN
# 4       Personal insgesamt  Personal insgesamt       Personal insgesamt
#
#     Biberach, LKR 426 Bodenseekreis, LKR 435 Ravensburg, LKR 436  \
# 0                 NaN                    NaN                 NaN
# 1                 NaN                    NaN                 NaN
# 2                 NaN                    NaN                 NaN
# 3                 NaN                    NaN                 NaN
# 4  Personal insgesamt     Personal insgesamt  Personal insgesamt
#
#   Sigmaringen, LKR 437   Baden-Württemberg
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4   Personal insgesamt  Personal insgesamt
#
# [5 rows x 46 columns]

# %%
df = pd.read_excel(PATH, sheetname='Pflegebedürftige', skiprows=4)
df = df.rename(columns={
    'Pflegestufen': 'key'
})

recipient_mapping = {
    'Pflegestufe I ': 'recipients_nursing_class_1',
    'Pflegestufe II ': 'recipients_nursing_class_2',
    'Pflegestufe III ': 'recipients_nursing_class_3',
    'Pflegestufe zugeordnet': 'recipients_nursing_class_unknown',
}


data.extend(list(get_column_values(df, recipient_mapping, 'recipients')))
df.head(30)
# Out:
# key
# Unnamed: 2
# Unnamed: 4
# Unnamed: 6
# Unnamed: 8
# Unnamed: 10
# Unnamed: 12
# Unnamed: 14
# Unnamed: 16
# Unnamed: 18
# Unnamed: 20
# Unnamed: 22
# Unnamed: 24
# Unnamed: 26
# Unnamed: 28
# Unnamed: 30
# Unnamed: 32
# Unnamed: 34
# Unnamed: 36
# Unnamed: 38
# Unnamed: 40
# Unnamed: 42
# Unnamed: 44
# Unnamed: 46
# Unnamed: 48
# Unnamed: 50
# Unnamed: 52
# Unnamed: 54
# Unnamed: 56
# Unnamed: 58
# Unnamed: 60
# Unnamed: 62
# Unnamed: 64
# Unnamed: 66
# Unnamed: 68
# Unnamed: 70
# Unnamed: 72
# Unnamed: 74
# Unnamed: 76
# Unnamed: 78
# Unnamed: 80
# Unnamed: 82
# Unnamed: 84
# Unnamed: 86
# Unnamed: 88
# Baden-Württemberg
# Unnamed: 90
#                           key          Stuttgart, SKR 111  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN  Pflegebedürftige insgesamt
# 5                         NaN                         NaN
# 6                         NaN                         NaN
# 7                         NaN                   Insgesamt
# 8                   Insgesamt                        5292
# 9   Pflegestufe I                                    2084
# 10  Pflegestufe II                                   2018
# 11  Pflegestufe III                                  1056
# 12  Bisher noch keiner                                NaN
# 13   Pflegestufe zugeordnet                           134
# 14                        NaN                         NaN
# 15                        NaN                         NaN
# 16                        NaN                         NaN
# 17                        NaN                         NaN
# 18                        NaN                         NaN
#
#                         Unnamed: 2          Böblingen, LKR 115  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4   vollstationäre Pflege zusammen  Pflegebedürftige insgesamt
# 5                              NaN                         NaN
# 6                              NaN                         NaN
# 7                              NaN                         NaN
# 8                             4996                        2864
# 9                             1958                        1117
# 10                            1893                        1171
# 11                            1022                         541
# 12                             NaN                         NaN
# 13                             123                          35
# 14                             NaN                         NaN
# 15                             NaN                         NaN
# 16                             NaN                         NaN
# 17                             NaN                         NaN
# 18                             NaN                         NaN
#
#                         Unnamed: 4          Esslingen, LKR 116  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4   vollstationäre Pflege zusammen  Pflegebedürftige insgesamt
# 5                              NaN                         NaN
# 6                              NaN                         NaN
# 7                              NaN                         NaN
# 8                             2641                        4053
# 9                             1024                        1536
# 10                            1075                        1720
# 11                             527                         714
# 12                             NaN                         NaN
# 13                              15                          83
# 14                             NaN                         NaN
# 15                             NaN                         NaN
# 16                             NaN                         NaN
# 17                             NaN                         NaN
# 18                             NaN                         NaN
#
#                         Unnamed: 6          Göppingen, LKR 117  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4   vollstationäre Pflege zusammen  Pflegebedürftige insgesamt
# 5                              NaN                         NaN
# 6                              NaN                         NaN
# 7                              NaN                         NaN
# 8                             3774                        2252
# 9                             1393                         913
# 10                            1607                         871
# 11                             698                         423
# 12                             NaN                         NaN
# 13                              76                          45
# 14                             NaN                         NaN
# 15                             NaN                         NaN
# 16                             NaN                         NaN
# 17                             NaN                         NaN
# 18                             NaN                         NaN
#
#                         Unnamed: 8        Ludwigsburg, LKR 118  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4   vollstationäre Pflege zusammen  Pflegebedürftige insgesamt
# 5                              NaN                         NaN
# 6                              NaN                         NaN
# 7                              NaN                         NaN
# 8                             2049                        4030
# 9                              812                        1603
# 10                             795                        1688
# 11                             407                         708
# 12                             NaN                         NaN
# 13                              35                          31
# 14                             NaN                         NaN
# 15                             NaN                         NaN
# 16                             NaN                         NaN
# 17                             NaN                         NaN
# 18                             NaN                         NaN
#
#                  ...                         Biberach, LKR 426  \
# 0                ...                                       NaN
# 1                ...                                       NaN
# 2                ...                                       NaN
# 3                ...                                       NaN
# 4                ...                Pflegebedürftige insgesamt
# 5                ...                                       NaN
# 6                ...                                       NaN
# 7                ...                                       NaN
# 8                ...                                      1642
# 9                ...                                       627
# 10               ...                                       662
# 11               ...                                       317
# 12               ...                                       NaN
# 13               ...                                        36
# 14               ...                                       NaN
# 15               ...                                       NaN
# 16               ...                                       NaN
# 17               ...                                       NaN
# 18               ...                                       NaN
#
#                        Unnamed: 82      Bodenseekreis, LKR 435  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4   vollstationäre Pflege zusammen  Pflegebedürftige insgesamt
# 5                              NaN                         NaN
# 6                              NaN                         NaN
# 7                              NaN                         NaN
# 8                             1462                        1636
# 9                              547                         536
# 10                             582                         670
# 11                             299                         374
# 12                             NaN                         NaN
# 13                              34                          56
# 14                             NaN                         NaN
# 15                             NaN                         NaN
# 16                             NaN                         NaN
# 17                             NaN                         NaN
# 18                             NaN                         NaN
#
#                        Unnamed: 84         Ravensburg, LKR 436  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4   vollstationäre Pflege zusammen  Pflegebedürftige insgesamt
# 5                              NaN                         NaN
# 6                              NaN                         NaN
# 7                              NaN                         NaN
# 8                             1541                        2570
# 9                              500                         953
# 10                             632                        1018
# 11                             357                         536
# 12                             NaN                         NaN
# 13                              52                          63
# 14                             NaN                         NaN
# 15                             NaN                         NaN
# 16                             NaN                         NaN
# 17                             NaN                         NaN
# 18                             NaN                         NaN
#
#                        Unnamed: 86        Sigmaringen, LKR 437  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4   vollstationäre Pflege zusammen  Pflegebedürftige insgesamt
# 5                              NaN                         NaN
# 6                              NaN                         NaN
# 7                              NaN                         NaN
# 8                             2390                        1041
# 9                              882                         389
# 10                             935                         438
# 11                             511                         203
# 12                             NaN                         NaN
# 13                              62                          11
# 14                             NaN                         NaN
# 15                             NaN                         NaN
# 16                             NaN                         NaN
# 17                             NaN                         NaN
# 18                             NaN                         NaN
#
#                        Unnamed: 88           Baden-Württemberg  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4   vollstationäre Pflege zusammen  Pflegebedürftige insgesamt
# 5                              NaN                         NaN
# 6                              NaN                         NaN
# 7                              NaN                         NaN
# 8                              912                       98781
# 9                              326                       37345
# 10                             387                       40262
# 11                             189                       18878
# 12                             NaN                         NaN
# 13                              10                        2296
# 14                             NaN                         NaN
# 15                             NaN                         NaN
# 16                             NaN                         NaN
# 17                             NaN                         NaN
# 18                             NaN                         NaN
#
#                        Unnamed: 90
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4   vollstationäre Pflege zusammen
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                            90845
# 9                            33862
# 10                           36888
# 11                           18063
# 12                             NaN
# 13                            2032
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
#
# [19 rows x 91 columns]

# %%
df = pd.DataFrame(data)
df = df.rename(columns={
    0: 'ags',
    1: 'type',
    2: 'key',
    3: 'value'
})
df['state'] = 'Baden-Württemberg'

part_time = df.groupby('ags').apply(lambda x: x[x['key'].str.contains('part-time')]['value'].sum()).reset_index()
part_time['state'] = 'Baden-Württemberg'
part_time['type'] = 'personal'
part_time['key'] = 'part-time'
part_time = part_time.rename(columns={0: 'value'})
df = df[~df['key'].str.contains('part-time')]
df = pd.concat([df, part_time])

df.to_csv('baden-wuerttemberg.csv', index=False)
df.head()
# Out:
#      ags                    key              state   type  value
# 0  08111                   food  Baden-Württemberg  costs  24.31
# 1  08111  costs_nursing_class_3  Baden-Württemberg  costs  95.98
# 2  08111  costs_nursing_class_1  Baden-Württemberg  costs  58.54
# 3  08111  costs_nursing_class_2  Baden-Württemberg  costs  75.29
# 4  08115                   food  Baden-Württemberg  costs  23.55
