# %%
import re
import pandas as pd

# %%
AGS_RE = re.compile('^(\d{5}).*', re.M)
data = []
PATH = 'raw/Pflegestatistik_2013_Sachsen.xls'

# %%
df = pd.read_excel(PATH, sheetname='tab_s61_Vergütung', skiprows=8)

df = df.rename(columns={
    'Unnamed: 0': 'key'
})
cost_mapping = {
    'Pflegeklasse 1': 'costs_nursing_class_1',
    'Pflegeklasse 2': 'costs_nursing_class_2',
    'Pflegeklasse 3': 'costs_nursing_class_3',
    'Verpflegung': 'food',
}

def get_column_values(df, mapping, prefix):
    for c in df.columns:
        ags = AGS_RE.match(c)
        if ags is None:
            continue
        ags = ags.group(1)

        for k, v in mapping.items():
            val = df[df['key'].str.contains(k).fillna(False)].iloc[0][c]
            yield ags, prefix, v, val


data.extend(list(get_column_values(df, cost_mapping, 'costs')))
df.head()
# Out:
#                               key  Unnamed: 1  145\nNuts2-Region\nChemnitz  \
# 0                             NaN         NaN                          NaN
# 1                             NaN         NaN                          NaN
# 2                             NaN         NaN                          NaN
# 3  Vergütung für vollstationäre           NaN                          NaN
# 4   Dauerpflege                           NaN                          NaN
#
#    14511\nKreisfrei Chemnitz  14521\nErzgebirgskreis  14522\nLK Mittelsachsen  \
# 0                        NaN                     NaN                      NaN
# 1                        NaN                     NaN                      NaN
# 2                        NaN                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                        NaN                     NaN                      NaN
#
#    14523\nVogtlandkreis  14524\nLK Zwickau  146\nNuts2-Region\nDresden  \
# 0                   NaN                NaN                         NaN
# 1                   NaN                NaN                         NaN
# 2                   NaN                NaN                         NaN
# 3                   NaN                NaN                         NaN
# 4                   NaN                NaN                         NaN
#
#    14612\nKreisfrei Dresden  14625\nLK Bautzen  14626\nLK Görlitz  \
# 0                       NaN                NaN                NaN
# 1                       NaN                NaN                NaN
# 2                       NaN                NaN                NaN
# 3                       NaN                NaN                NaN
# 4                       NaN                NaN                NaN
#
#    14627\nLK Meißen  14628\nLK Sächsische Schweiz-\nOsterzgebirge  \
# 0               NaN                                           NaN
# 1               NaN                                           NaN
# 2               NaN                                           NaN
# 3               NaN                                           NaN
# 4               NaN                                           NaN
#
#    147\nNuts2-Region\nLeipzig  14713\nKreisfrei Leipzig  14729\nLK Leipzig  \
# 0                         NaN                       NaN                NaN
# 1                         NaN                       NaN                NaN
# 2                         NaN                       NaN                NaN
# 3                         NaN                       NaN                NaN
# 4                         NaN                       NaN                NaN
#
#    14730\nLK Nordsachsen
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
df = pd.read_excel(PATH, sheetname='tab_s22_Verfügbare Plätze', skiprows=7)

df = df.rename(columns={
    'Unnamed: 0': 'key'
})
bed_mapping = {
  '1-Bett-Zimmern': '1-bed',
  '2-Bett-Zimmern': '2-bed',
  '3-Bett-Zimmern': '3-bed',
  '4 und mehr-Bett-Zimmern': '4-bed'
}

data.extend(list(get_column_values(df, bed_mapping, 'beds')))
df.head()
# Out:
#                                                  key  Unnamed: 1  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                                ...         NaN
# 3                Anzahl verfügbare Plätze insgesamt      51741.0
# 4                                                NaN         NaN
#
#    145\nNuts2-Region\nChemnitz  14511\nKreisfrei Chemnitz  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                      19945.0                     3362.0
# 4                          NaN                        NaN
#
#    14521\nErzgebirgskreis  14522\nLK Mittelsachsen  14523\nVogtlandkreis  \
# 0                     NaN                      NaN                   NaN
# 1                     NaN                      NaN                   NaN
# 2                     NaN                      NaN                   NaN
# 3                  4188.0                   3997.0                3401.0
# 4                     NaN                      NaN                   NaN
#
#    14524\nLK Zwickau  146\nNuts2-Region\nDresden  14612\nKreisfrei Dresden  \
# 0                NaN                         NaN                       NaN
# 1                NaN                         NaN                       NaN
# 2                NaN                         NaN                       NaN
# 3             4997.0                     19744.0                    5942.0
# 4                NaN                         NaN                       NaN
#
#    14625\nLK Bautzen  14626\nLK Görlitz  14627\nLK Meißen  \
# 0                NaN                NaN               NaN
# 1                NaN                NaN               NaN
# 2                NaN                NaN               NaN
# 3             3672.0             3865.0            2878.0
# 4                NaN                NaN               NaN
#
#    14628\nLK Sächsische Schweiz-\nOsterzgebirge  147\nNuts2-Region\nLeipzig  \
# 0                                           NaN                         NaN
# 1                                           NaN                         NaN
# 2                                           NaN                         NaN
# 3                                        3387.0                     12052.0
# 4                                           NaN                         NaN
#
#    14713\nKreisfrei Leipzig  14729\nLK Leipzig  14730\nLK Nordsachsen
# 0                       NaN                NaN                    NaN
# 1                       NaN                NaN                    NaN
# 2                       NaN                NaN                    NaN
# 3                    6351.0             3169.0                 2532.0
# 4                       NaN                NaN                    NaN

# %%
def get_values(df, mapping, prefix='personal', indicator='key', skip_on=None):
    ags = None
    cache = set()
    for i, row in df.iterrows():
        ind = str(row[indicator])
        if not pd.isnull(ind) and AGS_RE.match(ind) is not None:
            ags = ind.replace(' ', '')
        if ags is None:
            continue
        if pd.isnull(row['key']):
            continue
        if skip_on is not None and row['key'] in skip_on:
            ags = None
            continue
        for k, v in mapping.items():
            if k in row['key']:
                if ags == '14628' and v == 'recipients_nursing_class_1':
                    # WARNING: this was unparseable due to broken layout
                    # Watch out!
                    print('WARNING: inserting value artificially')
                    val = 1097.0
                elif isinstance(row['value'], str):
                    val = float(row['value'].replace('-', '0').strip())
                else:
                    val = row['value']
                cache_key = '%s-%s' % (ags, v)
                if cache_key not in cache:
                    yield ags, prefix, v, val
                    cache.add(cache_key)

                
df = pd.read_excel(PATH, sheetname='tab_s32_Personal', skiprows=11)

df = df.rename(columns={
    '14 Sachsen                   ': 'key',
    'Insgesamt                               ': 'value'
    
})

personal_mapping = {
    'Vollzeitbeschäftigt': 'fully_employed',
    'Teilzeitbeschäftigt': 'part-time',
    'Pflege und Betreuung': 'nursing_and_care',
    'soziale Betreuung': 'social_care',
    'zusätzliche Betreuung (§ 87b SGB XI)': 'other_care',
    'Personal insgesamt': 'total_personnel'
}


data.extend(list(get_values(df, personal_mapping)))
df.head()
# Out:
#                                                  key    value  Unnamed: 2  \
# 0                                                NaN      NaN         NaN
# 1  Personal insgesamt ..............................  34997.0     25446.0
# 2                                                NaN      NaN         NaN
# 3    Auszubildende/-r, (Um-)Schüler/-in ............   2123.0      1848.0
# 4                                                NaN      NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0         NaN         NaN         NaN         NaN
# 1      5581.0      2209.0       765.0       996.0
# 2         NaN         NaN         NaN         NaN
# 3       122.0        58.0        67.0        28.0
# 4         NaN         NaN         NaN         NaN

# %%
recipient_mapping = {
    'Pflegestufe I ': 'recipients_nursing_class_1',
    'Pflegestufe II ': 'recipients_nursing_class_2',
    'Pflegestufe III ': 'recipients_nursing_class_3',
    'Pflegestufe zugeordnet': 'recipients_nursing_class_unknown',
}

df = pd.read_excel(PATH, sheetname='tab_s42_Pflegebedürftige', skiprows=12)
df = df.rename(columns={
    'Sachsen': 'indicator',
    'Insgesamt': 'key',
    46509: 'value'
})

data.extend(list(get_values(df, recipient_mapping, indicator='indicator', prefix='recipients')))
df.head()
# Out:
# WARNING: inserting value artificially
#   indicator                        key    50534    value
# 0        14  Pflegestufe I              18000.0  15999.0
# 1       NaN  Pflegestufe II             22301.0  20674.0
# 2       NaN  Pflegestufe III             9966.0   9646.0
# 3       NaN  Bisher noch keiner             NaN      NaN
# 4       NaN   Pflegestufe zugeordnet      267.0    190.0

# %%
df = pd.DataFrame(data)
df = df.rename(columns={
    0: 'ags',
    1: 'type',
    2: 'key',
    3: 'value'
})
df['state'] = 'Sachsen'
df.to_csv('csvs/sachsen.csv', index=False)
df.head()
# Out:
#      ags   type                    key  value    state
# 0  14511  costs  costs_nursing_class_1  37.42  Sachsen
# 1  14511  costs  costs_nursing_class_2  49.03  Sachsen
# 2  14511  costs  costs_nursing_class_3  65.28  Sachsen
# 3  14511  costs                   food  15.24  Sachsen
# 4  14521  costs  costs_nursing_class_1  36.88  Sachsen

# %%
df[df['ags'] == '14628']
# Out:
#        ags        type                               key    value    state
# 36   14628       costs             costs_nursing_class_1    36.63  Sachsen
# 37   14628       costs             costs_nursing_class_2    48.46  Sachsen
# 38   14628       costs             costs_nursing_class_3    65.65  Sachsen
# 39   14628       costs                              food    15.65  Sachsen
# 88   14628        beds                             4-bed     0.00  Sachsen
# 89   14628        beds                             2-bed  1128.00  Sachsen
# 90   14628        beds                             1-bed  2047.00  Sachsen
# 91   14628        beds                             3-bed     0.00  Sachsen
# 158  14628    personal                   total_personnel  2262.00  Sachsen
# 159  14628    personal                  nursing_and_care  1594.00  Sachsen
# 160  14628    personal                       social_care    83.00  Sachsen
# 161  14628    personal                        other_care   140.00  Sachsen
# 162  14628    personal                    fully_employed   563.00  Sachsen
# 163  14628    personal                         part-time  1551.00  Sachsen
# 218  14628  recipients        recipients_nursing_class_2  1425.00  Sachsen
# 219  14628  recipients        recipients_nursing_class_3   519.00  Sachsen
# 220  14628  recipients  recipients_nursing_class_unknown    12.00  Sachsen
# 221  14628  recipients        recipients_nursing_class_1  1097.00  Sachsen
